# %% [markdown]
# # 네이버 API로 뉴스 받아오기
# API 신청하기: https://pinkwink.kr/1300

# %% [markdown]
# # json으로 크롤링하는 코드

# %%
# 네이버에서 삼성전자 뉴스 검색
import os
import sys
import urllib.request
client_id = "********************"
client_secret = "**********"
encText = urllib.parse.quote("삼성전자")

url = "https://openapi.naver.com/v1/search/news.json?query=" + encText + "&display=" + str(display) + "&sort=sim" 
# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

# 출처: https://developers.naver.com/docs/serviceapi/search/blog/blog.md#블로그
# Out:
# {
# "lastBuildDate": "Tue, 08 Jun 2021 15:01:39 +0900",
# "total": 2876425,
# "start": 1,
# "display": 30,
# "items": [
# {
# "title": "<b>삼성전자</b> &quot;V낸드도 결국 미세화 경쟁, 1000단 시대 주도할 것&quot;",
# "originallink": "http://www.edaily.co.kr/news/newspath.asp?newsid=02315686629079752",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=018&aid=0004951172",
# "description": "1000단 시대를 주도하겠다.” 송재혁 <b>삼성전자</b> 부사장(플래시 개발실장). (사진=<b>삼성전자</b>)“3D 스케일링 기술로 V낸드 높이 한계 극복” 송재혁(사진) <b>삼성전자</b>(005930) 부사장(플래시 개발실장)이 8일 뉴스룸을 통해... ",
# "pubDate": "Tue, 08 Jun 2021 12:21:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> &quot;명품 V낸드로 1천단 낸드 시대 주도할 것&quot;",
# "originallink": "http://yna.kr/AKR20210608064600003?did=1195m",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0012444564",
# "description": "송재혁 부사장 뉴스룸 기고문서 &quot;200단 8세대 V낸드 기술 확보&quot; 공개 하반기 출시 7세대 V낸드도 경쟁사 대비 크기 35% 줄여 <b>삼성전자</b>가 날로 기술경쟁이 치열해지는 낸드플래시 부문에서 현재 200단이 넘는 8세대 V낸드... ",
# "pubDate": "Tue, 08 Jun 2021 11:00:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> 노조, 오늘(7일) 첫 집단 산재 신청",
# "originallink": "http://news.tf.co.kr/read/economy/1866162.htm",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=629&aid=0000087429",
# "description": "광주광역시 근로복지공단 광산지사에 산업재해 보상 신청 진행 <b>삼성전자</b> 노동조합이 오늘(7일) 집단 산업재해 신청에 나선다. <b>삼성전자</b> 노조의 집단 산재 신청은 사상 최초다. 업계에 따르면 <b>삼성전자</b> 최대 노조인... ",
# "pubDate": "Mon, 07 Jun 2021 08:06:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> 노조, 첫 '집단 산재' 신청…&quot;업무상 질환&quot;",
# "originallink": "https://news.jtbc.joins.com/article/article.aspx?news_id=NB12008667",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=437&aid=0000268236",
# "description": "<b>삼성전자</b> 노조가 처음으로 집단 산업재해 신청을 했는데요. 가전제품을 주로 생산하는 사업장에서 일하는 노동자들이 오랫동안 반복적으로 무거운 물건을 다루면서 병이 생겼다는 겁니다. 노조는 앞으로 2차, 3차... ",
# "pubDate": "Tue, 08 Jun 2021 08:07:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> 20대 직원 백신 예약?…당국 &quot;일반 회사원 예약 취소&quot;",
# "originallink": "http://news.mt.co.kr/mtview.php?no=2021060714312664494",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=008&aid=0004598104",
# "description": "앞서 온라인 커뮤니티 등에선 <b>삼성전자</b> 등 일부 기업의 30세 미만 직원이 화이자 백신 예방접종 예약이 가능하다는 소문이 퍼졌다. 실제 일부 20대 일반 회사원의 예방접종 예약이 성사된 경우도 있는 것으로 알려졌다.... ",
# "pubDate": "Mon, 07 Jun 2021 14:33:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> 노조, 첫 집단 산재 신청…&quot;작업환경 개선 필요&quot;",
# "originallink": "https://view.asiae.co.kr/article/2021060715571962942",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=277&aid=0004915944",
# "description": "<b>삼성전자</b> 노동조합이 집단 산업재해를 신청했다. <b>삼성전자</b> 노조가 집단으로 산재를 신청한 것은 이번이 처음이다. <b>삼성전자</b> 내 최대규모 노조인 한국노총 소속 전국<b>삼성전자</b>노동조합은 7일 오전 광주광역시... ",
# "pubDate": "Mon, 07 Jun 2021 15:56:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> 네오 QLED, 독일 VDE '공간 최적화 사운드' 인증",
# "originallink": "https://www.sedaily.com/NewsView/22NK1QHYEC",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=011&aid=0003920494",
# "description": "<b>삼성전자</b>는 <b>삼성</b> 네오 QLED가 독일 인증 기관 VDE의 ‘공간 최적화 사운드’ 기술을 업계 최초로 인증받았다고 8일 밝혔다. 공간 최적화 사운드는 서로 다른 2개 시청 환경에서 TV 기술을 적용했을 때, 동일한 수준으로... ",
# "pubDate": "Tue, 08 Jun 2021 12:00:00 +0900"
#
# },
# {
# "title": "&quot;<b>삼성전자</b> 직원 화이자 접종&quot; 소문…정부 실수로 '백신 광클'",
# "originallink": "https://www.hankyung.com/society/article/2021060733491",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=015&aid=0004558744",
# "description": "“반도체 회사에 다니는 30세 미만 직원은 다 화이자 백신 맞는다네요.” “국가 기반시설, 공기업 직원이면 웬만하면 될 거 같으니 다들 한번 넣어보세요.” 방역당국이 <b>삼성전자</b>, SK하이닉스, 포스코 등 일부 대기업의... ",
# "pubDate": "Mon, 07 Jun 2021 17:44:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> &quot;V낸드도 결국 미세화, 1000단 시대 주도할 것&quot;",
# "originallink": "http://www.fnnews.com/news/202106081006140233",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004653211",
# "description": "&quot;향후 1000단 V낸드 시대에도 <b>삼성전자</b>가 시장을 주도하겠다&quot; 송재혁 <b>삼성전자</b> 플래시 개발실장 부사장이 8일 자사 뉴스룸을 통해 이 같은 내용을 담은 <b>삼성전자</b> V낸드의 혁신과 가치에 대한 기고문을 게재했다. 송... ",
# "pubDate": "Tue, 08 Jun 2021 11:01:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b>, 초격차 기술로 '1천단 V낸드' 시대 이끈다",
# "originallink": "http://www.inews24.com/view/1374191",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=031&aid=0000603194",
# "description": "글로벌 메모리 반도체 시장을 주도하고 있는 <b>삼성전자</b>가 낸드플래시 부문에서 200단이 넘는 8세대 V낸드 기술을 확보한 것을 바탕으로 향후 '1천단 적층 시대'를 주도할 것이란 포부를 드러냈다. 송재혁 <b>삼성전자</b>... ",
# "pubDate": "Tue, 08 Jun 2021 14:29:00 +0900"
#
# },
# {
# "title": "&quot;V낸드 1000단 시대도 <b>삼성전자</b>가 주도할 것&quot;",
# "originallink": "https://view.asiae.co.kr/article/2021060810375074955",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=277&aid=0004916395",
# "description": "다가올 1000단 시대에서도 <b>삼성전자</b>가 시장을 주도할 것이다.&quot; 송재혁 <b>삼성전자</b> 플래시 개발실장 부사장은 8일 <b>삼성</b> 뉴스룸에 게재한 기고문에서 &quot;<b>삼성전자</b>는 업계 최소 셀 사이즈를 구현한 3D 스케일링(미세화) 기술로... ",
# "pubDate": "Tue, 08 Jun 2021 11:00:00 +0900"
#
# },
# {
# "title": "[영상] <b>삼성전자</b> 노조, 첫 집단 산재 신청 &quot;심각한 근골격계 질환&quot;",
# "originallink": "http://yna.kr/AKR20210607133500704?did=1195m",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=001&aid=0012443423",
# "description": "<b>삼성전자</b> 노동조합이 처음으로 집단 산업재해 신청을 했습니다. <b>삼성전자</b> 내 최대규모 노조인 한국노총 소속 전국<b>삼성전자</b>노동조합은 7일 오전 광주광역시 근로복지공단 광산지사를 방문해 <b>삼성전자</b> 광주사업장 소속... ",
# "pubDate": "Mon, 07 Jun 2021 17:05:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> 노조, 첫 집단 산재 신청…&quot;업무로 근골격계 질환&quot;",
# "originallink": "http://yna.kr/AKR20210605039200003?did=1195m",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=001&aid=0012440126",
# "description": "지난해 '산재 은폐' 논란 광주사업장 직원 7명 산재 보상 신청 <b>삼성전자</b> 노동조합이 처음으로 집단 산업재해 신청에 나선다. 6일 업계에 따르면 <b>삼성전자</b> 내 최대규모 노조인 한국노총 소속 전국<b>삼성전자</b>노동조합은 7일... ",
# "pubDate": "Sun, 06 Jun 2021 06:01:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> 근로자들 첫 '산재 신청'…&quot;근골격계 극심한 통증&quot;",
# "originallink": "https://imnews.imbc.com/replay/2021/nwdesk/article/6249148_34936.html",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=214&aid=0001123583",
# "description": "◀ 리포트 ▶ <b>삼성전자</b> 광주공장 노동자 A씨는 7년 동안 에어컨 부품을 조립하다 5년 전 손목에 큰 종양이 생겼습니다. 극심한 통증을 겪고 있지만 그동안 산재 신청을 할 수는 없었다고 합니다. [이원일/한국노총 <b>삼성전자</b>... ",
# "pubDate": "Mon, 07 Jun 2021 20:28:00 +0900"
#
# },
# {
# "title": "늘었다 줄었다 하는 <b>삼성전자</b> 'OLED <b>전자</b>피부'",
# "originallink": "https://www.hankyung.com/economy/article/2021060693091",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=015&aid=0004558139",
# "description": "<b>삼성전자</b>는 몸의 움직임에 따라 늘고 줄면서도 신체 정보를 정확하고 안정적으로 측정할 수 있는 디스플레이 기술(사진) 개발에 성공했다고 6일 밝혔다. <b>삼성전자</b> 종합기술원은 ‘스트레처블(Stretchable) 센서와 OLED... ",
# "pubDate": "Sun, 06 Jun 2021 17:43:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> '네오 QLED', 전문 장비 없이도 최적의 사운드",
# "originallink": "https://daily.hankooki.com/lpage/ittech/202106/dh20210608082746138240.htm?s_ref=nv",
# "link": "https://daily.hankooki.com/lpage/ittech/202106/dh20210608082746138240.htm?s_ref=nv",
# "description": "'공간 최적화 사운드' 기술 VDE 인증 획득 <b>삼성전자</b>는 네오(Neo) QLED가 업계 최초로 독일 인증기관 VDE(Verband Deutscher Elektrotechniker)의 ‘공간 최적화 사운드(Spatial Sound Optimization)’ 기술을 인증받았다고 8일 밝혔다.... ",
# "pubDate": "Tue, 08 Jun 2021 08:30:00 +0900"
#
# },
# {
# "title": "‘산재 은폐’ 적발 <b>삼성전자</b> 7명 첫 집단 산재 신청",
# "originallink": "http://www.hani.co.kr/arti/society/labor/998222.html",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=028&aid=0002547412",
# "description": "산업재해 보고의무를 위반한 사례가 다수 적발되는 등 산재 은폐·축소 논란이 일었던 <b>삼성전자</b> 광주사업장에서 집단으로 산재 보상 신청이 제기된다. 한국노동조합총연맹 전국<b>삼성전자</b>노동조합은 조합원 7명이... ",
# "pubDate": "Sun, 06 Jun 2021 19:07:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> 노조, 광주서 첫 집단 산재 보상 신청",
# "originallink": "https://www.nocutnews.co.kr/news/5566468",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=079&aid=0003513026",
# "description": "<b>삼성전자</b> 노조가 산업재해 보상을 신청했다. <b>삼성전자</b> 노조가 집단 산재를 신청한 것은 이번이 처음이다. 7일 한국노총 소속 전국<b>삼성전자</b>노동조합(이하 <b>삼성전자</b> 노조)에 따르면 <b>삼성전자</b> 노조는 이날 오전 광주시... ",
# "pubDate": "Mon, 07 Jun 2021 19:18:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> “8세대 V낸드 기술 확보...1000단 시대 주도”",
# "originallink": "http://news.heraldcorp.com/view.php?ud=20210608000496",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=016&aid=0001845604",
# "description": "<b>삼성전자</b>가 올해 하반기 7세대 176단 V낸드가 적용된 소비자용 솔리드스테이트드라이브(SSD)를 출시한다. 이를 바탕으로 8세대 V낸드를 비롯해 향후 ‘1000단(段) 적층 시대’를 주도한다는 계획이다. 8일 송재혁(사진)... ",
# "pubDate": "Tue, 08 Jun 2021 11:21:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b>, 200단 8세대 V낸드 기술 확보…1000단 시대도 주도",
# "originallink": "https://www.etoday.co.kr/news/view/2033664",
# "link": "https://www.etoday.co.kr/news/view/2033664",
# "description": "이투데이=권태성 기자 | 메모리사업부 플래시 개발실장 송재혁 부사장 뉴스룸에 기고문 <b>삼성전자</b>가 고적층 V낸드플래시 기술로 미래 낸드 시장을 주도해나가겠다고 밝혔다. <b>삼성전자</b>는 올 하반기 7세대 V낸드를... ",
# "pubDate": "Tue, 08 Jun 2021 13:46:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> “8세대 V낸드 기술 확보…1000단 시대 주도”",
# "originallink": "http://news.heraldcorp.com/view.php?ud=20210608000398",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=016&aid=0001845567",
# "description": "<b>삼성전자</b>가 올해 하반기 7세대 176단 V낸드가 적용된 소비자용 솔리드스테이트드라이브(SSD)를 출시한다. 이를 바탕으로 8세대 V낸드를 비롯해 향후 ‘1000단 적층 시대’를 주도한다는 계획이다. 8일 송재혁 <b>삼성전자</b>... ",
# "pubDate": "Tue, 08 Jun 2021 11:02:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> &quot;200단 넘는 8세대 V낸드 기술 확보…미래 낸드 시대 주도할 것&quot;",
# "originallink": "http://www.etnews.com/20210608000155",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=030&aid=0002949520",
# "description": "<b>삼성전자</b>가 200단이 넘는 8세대 V낸드플래시 기술을 확보했다고 공식화했다. <b>삼성전자</b>만의 초고단 적층 기술을 앞세워, 향후 1000단 V낸드 시대에도 시장을 주도할 것이라고 자신했다. 송재혁 <b>삼성전자</b> 플래시개발실장... ",
# "pubDate": "Tue, 08 Jun 2021 13:49:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b>, 반도체 공장 곳곳 ESG 경영실천",
# "originallink": "http://www.fnnews.com/news/202106051557109924",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004652655",
# "description": "<b>삼성전자</b>가 반도체 공장에서의 친환경 활동에 박차를 가하고 있다. 지속가능한 미래를 위한 기업의 사회적 책임을 다하기 위한 환경·사회·지배구조(ESG) 경영의 일환이다. 7일 관련 업계에 따르면 <b>삼성전자</b>는... ",
# "pubDate": "Mon, 07 Jun 2021 15:57:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> 노조, 첫 '집단 산업재해' 신청",
# "originallink": "https://imnews.imbc.com/replay/2021/nw1200/article/6246400_34908.html",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=214&aid=0001123484",
# "description": "<b>삼성전자</b> 노동조합이 처음으로 집단 산업재해 신청을 했습니다. <b>삼성전자</b> 내 최대규모 노조인 한국노총 소속 전국<b>삼성전자</b>노동조합은 오늘 광주광역시 근로복지공단 광산지사를 방문해 <b>삼성전자</b> 광주사업장 소속 조합원... ",
# "pubDate": "Mon, 07 Jun 2021 12:13:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> &quot;8세대 V낸드 기술 확보… 향후 1천단 시대 주도&quot;",
# "originallink": "http://biz.newdaily.co.kr/site/data/html/2021/06/08/2021060800129.html",
# "link": "http://biz.newdaily.co.kr/site/data/html/2021/06/08/2021060800129.html",
# "description": "뉴데일리 조재범 기자 = <b>삼성전자</b>가 낸드플래시 시장에서 기술 우위 바탕으로 주도권을 이어가겠다는 포부를 밝혔다. <b>삼성전자</b>는 현재 200단이 넘는 8세대 V낸드 기술을 확보했으며, 향후 1천단 낸드 시대도... ",
# "pubDate": "Tue, 08 Jun 2021 14:50:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> 노조, 첫 집단 산재 신청…&quot;작업환경 개선해야&quot;",
# "originallink": "http://yna.kr/AKR20210607058700003?did=1195m",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=001&aid=0012442065",
# "description": "광주사업장 직원 7명, 근골격계 질환으로 산업재해 보상 신청 정회성 김철선 기자 = <b>삼성전자</b> 노동조합이 처음으로 집단 산업재해 신청을 했다. <b>삼성전자</b> 내 최대규모 노조인 한국노총 소속 전국<b>삼성전자</b>노동조합은 7일... ",
# "pubDate": "Mon, 07 Jun 2021 10:53:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> &quot;하반기 7세대 V낸드 적용 SSD 출시…8세대 기술도 확보&quot;",
# "originallink": "https://daily.hankooki.com/lpage/ittech/202106/dh20210608142102138240.htm?s_ref=nv",
# "link": "https://daily.hankooki.com/lpage/ittech/202106/dh20210608142102138240.htm?s_ref=nv",
# "description": "송재혁 부사장 &quot;200단 넘는 8세대 V낸드 동작 칩 기술력 갖춰&quot; <b>삼성전자</b>가 차세대 기술로 낸드플래시 시장을 주도할 것이란 자신감을 내비쳤다. <b>삼성전자</b>의 플래시 개발실장 송재혁 부사장은 8일 <b>삼성전자</b> 뉴스룸... ",
# "pubDate": "Tue, 08 Jun 2021 14:26:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> &quot;200단 8세대 낸드 기술 확보, 1000단 시대 주도할 것&quot;",
# "originallink": "http://www.dt.co.kr/contents.html?article_no=2021060802109932781001&ref=naver",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=029&aid=0002679019",
# "description": "<b>삼성전자</b>가 200단 이상의 8세대 V낸드플래시 기술을 확보하고 조만간 제품을 선보인다. 수직적층 경쟁력 등을 한층 강화해 1000단 이상 초미세공정 메모리 기술에서도 '초격차'를 유지한다는 포부를 내놓았다. 송재혁... ",
# "pubDate": "Tue, 08 Jun 2021 13:48:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> Neo QLED, VDE 인증 획득…업계 최초 인증 3개",
# "originallink": "http://www.sisaon.co.kr/news/articleView.html?idxno=128239",
# "link": "http://www.sisaon.co.kr/news/articleView.html?idxno=128239",
# "description": "삼성전자는 Neo QLED가 업계 최초로 독일 인증기관 VDE의 '공간 최적화 사운드' 기술을 인증 받았다고 8일 밝혔다. ⓒ<b>삼성전자 삼성전자</b>는 Neo QLED가 업계 최초로 독일 인증기관 VDE의 '공간 최적화 사운드' 기술을 인증... ",
# "pubDate": "Tue, 08 Jun 2021 14:22:00 +0900"
#
# },
# {
# "title": "<b>삼성전자</b> 노조, 첫 집단 산재 신청…&quot;작업환경 개선해야&quot;",
# "originallink": "https://imnews.imbc.com/news/2021/econo/article/6247099_34887.html",
# "link": "https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=214&aid=0001123504",
# "description": "<b>삼성전자</b> 노동조합이 처음으로 집단 산업재해 신청을 했습니다. <b>삼성전자</b> 내 최대규모 노조인 한국노총 소속 전국<b>삼성전자</b>노동조합은 오늘 오전 광주광역시 근로복지공단 광산지사를 방문해 <b>삼성전자</b> 광주사업장 소속... ",
# "pubDate": "Mon, 07 Jun 2021 14:25:00 +0900"
#
# }
# ]
# }

# %%
type(response_body.decode('utf-8'))
# Out:
# str

# %% [markdown]
# # 크롤링 데이터 dict형태로 바꾼 후, DataFrame으로 바꾸기

# %%
# 네이버에서 삼성전자 뉴스 검색
import os
import sys
import urllib.request
client_id = "9yZWf6rCY3Zt0G6Q1yDl"
client_secret = "hHoUE6mB57"
encText = urllib.parse.quote("삼성전자")

url = "https://openapi.naver.com/v1/search/news.json?query=" + encText + "&display=" + str(display) + "&sort=sim" 
# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)



response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body_str = response.read().decode('utf-8')
    json_acceptable_string = response_body_str.replace("'", "\"")
    response_body = json.loads(response_body_str)
    print(response_body)
else:
    print("Error Code:" + rescode)

# 출처: https://developers.naver.com/docs/serviceapi/search/blog/blog.md#블로그
# Out:
# {'lastBuildDate': 'Tue, 08 Jun 2021 15:38:44 +0900', 'total': 2876470, 'start': 1, 'display': 30, 'items': [{'title': '<b>삼성전자</b> &quot;V낸드도 결국 미세화 경쟁, 1000단 시대 주도할 것&quot;', 'originallink': 'http://www.edaily.co.kr/news/newspath.asp?newsid=02315686629079752', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=018&aid=0004951172', 'description': '1000단 시대를 주도하겠다.” 송재혁 <b>삼성전자</b> 부사장(플래시 개발실장). (사진=<b>삼성전자</b>)“3D 스케일링 기술로 V낸드 높이 한계 극복” 송재혁(사진) <b>삼성전자</b>(005930) 부사장(플래시 개발실장)이 8일 뉴스룸을 통해... ', 'pubDate': 'Tue, 08 Jun 2021 12:21:00 +0900'}, {'title': '<b>삼성전자</b> &quot;명품 V낸드로 1천단 낸드 시대 주도할 것&quot;', 'originallink': 'http://yna.kr/AKR20210608064600003?did=1195m', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0012444564', 'description': '송재혁 부사장 뉴스룸 기고문서 &quot;200단 8세대 V낸드 기술 확보&quot; 공개 하반기 출시 7세대 V낸드도 경쟁사 대비 크기 35% 줄여 <b>삼성전자</b>가 날로 기술경쟁이 치열해지는 낸드플래시 부문에서 현재 200단이 넘는 8세대 V낸드... ', 'pubDate': 'Tue, 08 Jun 2021 11:00:00 +0900'}, {'title': '<b>삼성전자</b> 노조, 오늘(7일) 첫 집단 산재 신청', 'originallink': 'http://news.tf.co.kr/read/economy/1866162.htm', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=629&aid=0000087429', 'description': '광주광역시 근로복지공단 광산지사에 산업재해 보상 신청 진행 <b>삼성전자</b> 노동조합이 오늘(7일) 집단 산업재해 신청에 나선다. <b>삼성전자</b> 노조의 집단 산재 신청은 사상 최초다. 업계에 따르면 <b>삼성전자</b> 최대 노조인... ', 'pubDate': 'Mon, 07 Jun 2021 08:06:00 +0900'}, {'title': '<b>삼성전자</b> &quot;V낸드 1000단 시대도 주도할 것&quot;', 'originallink': 'https://www.hankyung.com/economy/article/202106086822g', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=015&aid=0004559294', 'description': '전 세계 1위 메모리 반도체 기업 <b>삼성전자</b>가 낸드플래시 부문에서 현재 200단이 넘는 8세대 V낸드 기술을 확보했다고 밝혔다. 또 향후 1000단 낸드 시대를 주도해나갈 것이라고 했다. 송재혁(사진) <b>삼성전자</b>... ', 'pubDate': 'Tue, 08 Jun 2021 15:22:00 +0900'}, {'title': "<b>삼성전자</b> 노조, 첫 '집단 산재' 신청…&quot;업무상 질환&quot;", 'originallink': 'https://news.jtbc.joins.com/article/article.aspx?news_id=NB12008667', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=437&aid=0000268236', 'description': '<b>삼성전자</b> 노조가 처음으로 집단 산업재해 신청을 했는데요. 가전제품을 주로 생산하는 사업장에서 일하는 노동자들이 오랫동안 반복적으로 무거운 물건을 다루면서 병이 생겼다는 겁니다. 노조는 앞으로 2차, 3차... ', 'pubDate': 'Tue, 08 Jun 2021 08:07:00 +0900'}, {'title': '&quot;V낸드 1000단 시대도 <b>삼성전자</b>가 주도할 것&quot;', 'originallink': 'https://view.asiae.co.kr/article/2021060810375074955', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=277&aid=0004916395', 'description': '다가올 1000단 시대에서도 <b>삼성전자</b>가 시장을 주도할 것이다.&quot; 송재혁 <b>삼성전자</b> 플래시 개발실장 부사장은 8일 <b>삼성</b> 뉴스룸에 게재한 기고문에서 &quot;<b>삼성전자</b>는 업계 최소 셀 사이즈를 구현한 3D 스케일링(미세화) 기술로... ', 'pubDate': 'Tue, 08 Jun 2021 11:00:00 +0900'}, {'title': '<b>삼성전자</b> 20대 직원 백신 예약?…당국 &quot;일반 회사원 예약 취소&quot;', 'originallink': 'http://news.mt.co.kr/mtview.php?no=2021060714312664494', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=008&aid=0004598104', 'description': '앞서 온라인 커뮤니티 등에선 <b>삼성전자</b> 등 일부 기업의 30세 미만 직원이 화이자 백신 예방접종 예약이 가능하다는 소문이 퍼졌다. 실제 일부 20대 일반 회사원의 예방접종 예약이 성사된 경우도 있는 것으로 알려졌다.... ', 'pubDate': 'Mon, 07 Jun 2021 14:33:00 +0900'}, {'title': "<b>삼성전자</b> 네오 QLED, 독일 VDE '공간 최적화 사운드' 인증", 'originallink': 'https://www.sedaily.com/NewsView/22NK1QHYEC', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=011&aid=0003920494', 'description': '<b>삼성전자</b>는 <b>삼성</b> 네오 QLED가 독일 인증 기관 VDE의 ‘공간 최적화 사운드’ 기술을 업계 최초로 인증받았다고 8일 밝혔다. 공간 최적화 사운드는 서로 다른 2개 시청 환경에서 TV 기술을 적용했을 때, 동일한 수준으로... ', 'pubDate': 'Tue, 08 Jun 2021 12:00:00 +0900'}, {'title': "<b>삼성전자</b> 근로자들 첫 '산재 신청'…&quot;근골격계 극심한 통증&quot;", 'originallink': 'https://imnews.imbc.com/replay/2021/nwdesk/article/6249148_34936.html', 'link': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=214&aid=0001123583', 'description': '◀ 리포트 ▶ <b>삼성전자</b> 광주공장 노동자 A씨는 7년 동안 에어컨 부품을 조립하다 5년 전 손목에 큰 종양이 생겼습니다. 극심한 통증을 겪고 있지만 그동안 산재 신청을 할 수는 없었다고 합니다. [이원일/한국노총 <b>삼성전자</b> ...

# %%
# 네이버에서 삼성전자 뉴스 검색
import os
import sys
import urllib.request
client_id = "9yZWf6rCY3Zt0G6Q1yDl"
client_secret = "hHoUE6mB57"
encText = urllib.parse.quote("삼성전자")

url = "https://openapi.naver.com/v1/search/news.json?query=" + encText + "&display=" + str(display) + "&sort=sim" 
# url = "https://openapi.naver.com/v1/search/blog?query=" + encText # json 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # xml 결과

request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)



response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body_str = response.read().decode('utf-8')
    json_acceptable_string = response_body_str.replace("'", "\"")
    response_body = json.loads(response_body_str)

    title_link={}
    for i in range(0, len(response_body['items'])):
      title_link[response_body['items'][i]['title']] = response_body['items'][i]['link']
    print(title_link)
else:
    print("Error Code:" + rescode)

# 출처: https://developers.naver.com/docs/serviceapi/search/blog/blog.md#블로그
# Out:
# {'<b>삼성전자</b> &quot;V낸드도 결국 미세화 경쟁, 1000단 시대 주도할 것&quot;': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=018&aid=0004951172', '<b>삼성전자</b> &quot;명품 V낸드로 1천단 낸드 시대 주도할 것&quot;': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=001&aid=0012444564', '<b>삼성전자</b> 노조, 오늘(7일) 첫 집단 산재 신청': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=629&aid=0000087429', '<b>삼성전자</b> &quot;V낸드 1000단 시대도 주도할 것&quot;': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=015&aid=0004559294', "<b>삼성전자</b> 노조, 첫 '집단 산재' 신청…&quot;업무상 질환&quot;": 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=437&aid=0000268236', '&quot;V낸드 1000단 시대도 <b>삼성전자</b>가 주도할 것&quot;': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=277&aid=0004916395', '<b>삼성전자</b> 20대 직원 백신 예약?…당국 &quot;일반 회사원 예약 취소&quot;': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=008&aid=0004598104', "<b>삼성전자</b> 네오 QLED, 독일 VDE '공간 최적화 사운드' 인증": 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=011&aid=0003920494', "<b>삼성전자</b> 근로자들 첫 '산재 신청'…&quot;근골격계 극심한 통증&quot;": 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=214&aid=0001123583', '<b>삼성전자</b> 노조, 광주서 첫 집단 산재 보상 신청': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=079&aid=0003513026', '<b>삼성전자</b> 노조, 첫 집단 산재 신청…&quot;작업환경 개선 필요&quot;': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=277&aid=0004915944', '[영상] <b>삼성전자</b> 노조, 첫 집단 산재 신청 &quot;심각한 근골격계 질환&quot;': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=001&aid=0012443423', '<b>삼성전자</b> &quot;V낸드도 결국 미세화, 1000단 시대 주도할 것&quot;': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004653211', "&quot;<b>삼성전자</b> 직원 화이자 접종&quot; 소문…정부 실수로 '백신 광클'": 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=015&aid=0004558744', '<b>삼성전자</b> 노조, 첫 집단 산재 신청…&quot;업무로 근골격계 질환&quot;': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=001&aid=0012440126', "늘었다 줄었다 하는 <b>삼성전자</b> 'OLED <b>전자</b>피부'": 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=015&aid=0004558139', "<b>삼성전자</b> '네오 QLED', 전문 장비 없이도 최적의 사운드": 'https://daily.hankooki.com/lpage/ittech/202106/dh20210608082746138240.htm?s_ref=nv', "<b>삼성전자</b>, 초격차 기술로 '1천단 V낸드' 시대 이끈다": 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=031&aid=0000603194', '<b>삼성전자</b> “8세대 V낸드 기술 확보...1000단 시대 주도”': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=016&aid=0001845604', '‘산재 은폐’ 적발 <b>삼성전자</b> 7명 첫 집단 산재 신청': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=102&oid=028&aid=0002547412', '<b>삼성전자</b>, 200단 8세대 V낸드 기술 확보…1000단 시대도 주도': 'https://www.etoday.co.kr/news/view/2033664', '<b>삼성전자</b> &quot;200단 넘는 8세대 V낸드 기술 확보…미래 낸드 시대 주도할 것&quot;': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=030&aid=0002949520', '<b>삼성전자</b> “8세대 V낸드 기술 확보…1000단 시대 주도”': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=016&aid=0001845567', '<b>삼성전자</b>, 반도체 공장 곳곳 ESG 경영실천': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=014&aid=0004652655', '<b>삼성전자</b> &quot;하반기 7세대 V낸드 적용 SSD 출시…8세대 기술도 확보&quot;': 'https://daily.hankooki.com/lpage/ittech/202106/dh20210608142102138240.htm?s_ref=nv', '<b>삼성전자</b> &quot;200단 8세대 낸드 기술 확보, 1000단 시대 주도할 것&quot;': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=101&oid=029&aid=0002679019', '<b>삼성전자</b> &quot;8세대 V낸드 기술 확보… 향후 1천단 시대 주도&quot;': 'http://biz.newdaily.co.kr/site/data/html/2021/06/08/2021060800129.html', '<b>삼성전자</b>, 네오QLED TV VDE ‘공간 최적화 사운드’ 인증 획득': 'https://news.naver.com/main/read.nhn?mode=LSD&mid=sec&sid1=105&oid=138&aid=0002104731', '<b>삼성전자</b> “200단 넘는 8세대 낸드 기술 확보”': 'https://www.dnews.co.kr/uhtml/view.jsp?idxno=202106081459004600829', "<b>삼성전자</b> 노조, 첫 '집단 산업재해' 신청": 'https://news.naver.com/main/read.nh ...

# %%
type(title_link)
# Out:
# dict

# %%
pd.DataFrame.from_dict(title_link, orient='index')
# Out:
#                                                                                                     0
# <b>삼성전자</b> &quot;V낸드도 결국 미세화 경쟁, 1000단 시대 주도할 ...  https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> &quot;명품 V낸드로 1천단 낸드 시대 주도할 것&quot;     https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> 노조, 오늘(7일) 첫 집단 산재 신청                   https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> &quot;V낸드 1000단 시대도 주도할 것&quot;         https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> 노조, 첫 '집단 산재' 신청…&quot;업무상 질환&quot;     https://news.naver.com/main/read.nhn?mode=LSD&...
# &quot;V낸드 1000단 시대도 <b>삼성전자</b>가 주도할 것&quot;        https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> 20대 직원 백신 예약?…당국 &quot;일반 회사원 예약 취소...  https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> 네오 QLED, 독일 VDE '공간 최적화 사운드' 인증         https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> 근로자들 첫 '산재 신청'…&quot;근골격계 극심한 통증&quot;  https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> 노조, 광주서 첫 집단 산재 보상 신청                   https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> 노조, 첫 집단 산재 신청…&quot;작업환경 개선 필요&quot;   https://news.naver.com/main/read.nhn?mode=LSD&...
# [영상] <b>삼성전자</b> 노조, 첫 집단 산재 신청 &quot;심각한 근골격계 ...  https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> &quot;V낸드도 결국 미세화, 1000단 시대 주도할 것&q...  https://news.naver.com/main/read.nhn?mode=LSD&...
# &quot;<b>삼성전자</b> 직원 화이자 접종&quot; 소문…정부 실수로 '백신...  https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> 노조, 첫 집단 산재 신청…&quot;업무로 근골격계 질환&quot;  https://news.naver.com/main/read.nhn?mode=LSD&...
# 늘었다 줄었다 하는 <b>삼성전자</b> 'OLED <b>전자</b>피부'           https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> '네오 QLED', 전문 장비 없이도 최적의 사운드            https://daily.hankooki.com/lpage/ittech/202106...
# <b>삼성전자</b>, 초격차 기술로 '1천단 V낸드' 시대 이끈다               https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> “8세대 V낸드 기술 확보...1000단 시대 주도”           https://news.naver.com/main/read.nhn?mode=LSD&...
# ‘산재 은폐’ 적발 <b>삼성전자</b> 7명 첫 집단 산재 신청                https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b>, 200단 8세대 V낸드 기술 확보…1000단 시대도 주도               https://www.etoday.co.kr/news/view/2033664
# <b>삼성전자</b> &quot;200단 넘는 8세대 V낸드 기술 확보…미래 낸드 시...  https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> “8세대 V낸드 기술 확보…1000단 시대 주도”             https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b>, 반도체 공장 곳곳 ESG 경영실천                     https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> &quot;하반기 7세대 V낸드 적용 SSD 출시…8세대 기술도...  https://daily.hankooki.com/lpage/ittech/202106...
# <b>삼성전자</b> &quot;200단 8세대 낸드 기술 확보, 1000단 시대 주...  https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> &quot;8세대 V낸드 기술 확보… 향후 1천단 시대 주도&q...  http://biz.newdaily.co.kr/site/data/html/2021/...
# <b>삼성전자</b>, 네오QLED TV VDE ‘공간 최적화 사운드’ 인증 획득       https://news.naver.com/main/read.nhn?mode=LSD&...
# <b>삼성전자</b> “200단 넘는 8세대 낸드 기술 확보”                  https://www.dnews.co.kr/uhtml/view.jsp?idxno=2...
# <b>삼성전자</b> 노조, 첫 '집단 산업재해' 신청                      https://news.naver.com/main/read.nhn?mode=LSD&...
